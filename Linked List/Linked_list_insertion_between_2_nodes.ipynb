# %%
class Node:    # Making a class node for storing data and having pointers.
    
    def __init__(self, data):   # Constructor for the variables.
        self.data = data
        self.next = None   # First data which points to none only.
        
class LinkedList:   # Class for linked list.
    
    def __init__(self):   # Setting the head to none in starting.
        self.head = None
    
    def insert(self, newnode):   # Function for inserting the new node in the linked list.
        if self.head is None:   # If linked list is empty made the newnode as first node.
            self.head = newnode
        else:
            x = self.head
            while True:    # Else we have to traverse through the linked list to reach at the end to add newnode.
                if x.next is None:
                    x.next = newnode
                    newnode.next = None
                    break
                x = x.next
            
    def insertbetween(self, newnode, position):
        if position == 0:   # If position is 0 we will call the insert function only.
            self.insert(newnode)
        elif position < 0:
            print('Invalid position.')
        else:
            i = 0
            x = self.head
            while True:
                if i == position:
                    firstnode.next = newnode   # Making connections between nodes.
                    newnode.next = secondnode   # Making the connection between newnode and its next node.
                    break
                firstnode = x   # Keeping the node of the position previous to the position to be added.
                secondnode = x.next   # Keeping the node of the position next to the position to be added. 
                x = x.next
                i+=1

    def printlist(self):   # Function for printing of the linked list.
        if self.head is None:   # If the list is empty.
            print('List is empty')
        else:
            x = self.head
            print(x.data)   # Printing the data in the node.
            while True:
                if x.next is None:
                    break
                x = x.next
                print(x.data)
    
n = int(input('Enter the number of elements in linked list : '))
linkedlist = LinkedList()
print('Enter the elements : ')

while n>0:
    node = int(input())
    NewNode = Node(node)
    linkedlist.insert(NewNode)
    n-=1
    
print('Linked list is : ')
linkedlist.printlist()

new, pos = map(int,input('Enter the element and position of the element you want to insert : ').split())
NewNode = Node(new)
linkedlist.insertbetween(NewNode, pos)
print('Your new linked list is : ')
linkedlist.printlist()
# Out:
# Enter the number of elements in linked list : 4
# Enter the elements :
# 1
# 2
# 4
# 5
# Linked list is :
# 1
# 2
# 4
# 5
# Enter the element and position of the element you want to insert : 3 2
# Your new linked list is :
# 1
# 2
# 3
# 4
# 5
